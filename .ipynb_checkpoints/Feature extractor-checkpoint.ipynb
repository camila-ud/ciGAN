# %%
from prepare import *
from model import *
# Out:
# Using TensorFlow backend.

# %%
# Reset the graph
tf.reset_default_graph()

# Start interactive session
sess = tf.InteractiveSession()

#tf: will scale pixels between -1 and 1, sample-wise.

# %%
data_generator = generate_cpatches(1)
data_X  = next(data_generator)
data_x = data_X[0:1, :, :, 0:1]
data_mask = data_X[0:1, :, :, 1:2]
data_real = data_X[0:1, :, :, 2:3]
data_boundary = data_X[:, :, :, 3:4]
# Out:
# g 1
# Patches size (1, 256, 256, 4)

# %%
patch_size = 256
input_x = tf.placeholder(tf.float32, [None, patch_size, patch_size, 1])
input_mask = tf.placeholder(tf.float32, [None, patch_size, patch_size, 1])
input_real = tf.placeholder(tf.float32, [None, patch_size, patch_size, 1])
input_boundary = tf.placeholder(tf.float32, [None, patch_size, patch_size, 1])

# %%
vgg_channels = build_vgg19(tf.multiply(input_real, 1 - input_mask))
vgg = build_vgg19(tf.multiply(input_real, input_mask))

# %%
vgg_boundary = build_vgg19(tf.multiply(input_real, input_boundary))

# %%
pred_img_c = sess.run(vgg_channels, feed_dict={
                    input_real: data_real,
                    input_mask: data_mask
                   })
pred_img = sess.run(vgg, feed_dict={
                    input_real: data_real,
                    input_mask: data_mask
                   })

# %%
pred_bound = sess.run(vgg_boundary, feed_dict={
                    input_real: data_real,
                    input_boundary: data_boundary
                   })

# %%
[(k,x.shape) for k,x in pred_img_c.items()]
# Out:
# [('input', (1, 256, 256, 3)),
#  ('conv1_1', (1, 256, 256, 64)),
#  ('conv1_2', (1, 256, 256, 64)),
#  ('pool1', (1, 128, 128, 64)),
#  ('conv2_1', (1, 128, 128, 128)),
#  ('conv2_2', (1, 128, 128, 128)),
#  ('pool2', (1, 64, 64, 128)),
#  ('conv3_1', (1, 64, 64, 256)),
#  ('conv3_2', (1, 64, 64, 256)),
#  ('conv3_3', (1, 64, 64, 256)),
#  ('conv3_4', (1, 64, 64, 256)),
#  ('pool3', (1, 32, 32, 256)),
#  ('conv4_1', (1, 32, 32, 512)),
#  ('conv4_2', (1, 32, 32, 512)),
#  ('conv4_3', (1, 32, 32, 512)),
#  ('conv4_4', (1, 32, 32, 512)),
#  ('pool4', (1, 16, 16, 512)),
#  ('conv5_1', (1, 16, 16, 512)),
#  ('conv5_2', (1, 16, 16, 512))]

# %%
def denorm(image):
    image += 1
    image *= 0.5
    return image

# %%
fig = plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(denorm(pred_img_c['input'][0,:,:,:]))
plt.xlabel("Vgg channel")
plt.subplot(1,2,2)
plt.imshow(denorm(pred_img['input'][0,:,:,:]))
plt.xlabel("Vgg inside")
# Out:
# Text(0.5, 0, 'Vgg inside')

# %% [markdown]
# ## pool1 inside

# %%
feature_maps = pred_img['pool1']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## pool3 inside

# %%
feature_maps = pred_img['pool3']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## pool4 inside

# %%
feature_maps = pred_img['pool4']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## pool1 offside

# %%
feature_maps = pred_img_c['pool1']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## pool3 offside

# %%
feature_maps = pred_img_c['pool3']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## pool4 offside

# %%
feature_maps = pred_img_c['pool4']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## pool1 boundary

# %%
feature_maps = pred_bound['pool1']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## pool3 boundary

# %%
feature_maps = pred_bound['pool3']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# ## pool4 boundary

# %%
feature_maps = pred_bound['pool4']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %%
feature_maps = pred_img['conv5_2']
square = 8
ix = 1
fig = plt.figure(figsize= (15,15))
for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = plt.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		plt.imshow(feature_maps[0, :, :, ix-1])
		ix += 1
# show the figure
plt.show()

# %% [markdown]
# Test 10 mars
#
#
# ####test 10mars
#         vgg_real_c = build_vgg19(tf.multiply(self.input_real, 1 - self.input_mask))
#         vgg_fake_c = build_vgg19(tf.multiply(self.fake_image, 1 - self.input_mask), reuse=True)
#
#         #    Extract VGG weights
#         G_loss_vgg = tf.reduce_mean(tf.abs(vgg_real_c['input'] - vgg_fake_c['input']))
#
#         vgg_real = build_vgg19(tf.multiply(self.input_real, self.input_mask))
#         vgg_fake = build_vgg19(tf.multiply(self.fake_image, self.input_mask), reuse=True)
#
#         #add importance inside 100 no mejora
#         G_loss_vgg = tf.reduce_mean(tf.abs(vgg_real['input'] - vgg_fake['input']))
#
#         for i in range(1, 4):
#             conv_str = 'pool' + str(i)
#             #add importance ?
#             G_loss_vgg += tf.reduce_mean(tf.abs(vgg_real[conv_str] - vgg_fake[conv_str]))
#
#         vgg_real = build_vgg19(tf.multiply(self.input_real, self.input_boundary))
#         vgg_fake = build_vgg19(tf.multiply(self.fake_image, self.input_boundary), reuse=True)
#
#         G_loss_vgg += tf.reduce_mean(tf.abs(vgg_real['input'] - vgg_fake['input']))
#         for i in range(1, 4):
#             conv_str = 'pool' + str(i)
#             G_loss_vgg += tf.reduce_mean(tf.abs(vgg_real[conv_str] - vgg_fake[conv_str]))

# %%
##change vgg only inside

# %%
sess.close()
